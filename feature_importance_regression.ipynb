# %%
# Imports all the libraries
import pandas as pd

# %%
# read the dataset
dataset1=pd.read_csv("prep.csv",index_col=None)

# %%
# copy the dataset to df2
df2=dataset1

# %%
# Print the dataset
df2
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# ...

# %%
# Convert the categorical data to numerical data using get_dummies
df2 = pd.get_dummies(df2, drop_first=True)

# %%
# print the updated data
df2
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  pc_normal  pcc_present  ba_present  \
# ...

# %%
# Get independent and dependent variables
indep_X=df2.drop(columns='classification_yes', axis=1)
dep_Y=df2['classification_yes']

# %%
# Print the indep_X
indep_X
# Out:
#            age         bp   al   su         bgr          bu        sc  \
# 0     2.000000  76.459948  3.0  0.0  148.112676   57.482105  3.077356
# 1     3.000000  76.459948  2.0  0.0  148.112676   22.000000  0.700000
# 2     4.000000  76.459948  1.0  0.0   99.000000   23.000000  0.600000
# 3     5.000000  76.459948  1.0  0.0  148.112676   16.000000  0.700000
# 4     5.000000  50.000000  0.0  0.0  148.112676   25.000000  0.600000
# ..         ...        ...  ...  ...         ...         ...       ...
# 394  51.492308  70.000000  0.0  0.0  219.000000   36.000000  1.300000
# 395  51.492308  70.000000  0.0  2.0  220.000000   68.000000  2.800000
# 396  51.492308  70.000000  3.0  0.0  110.000000  115.000000  6.000000
# 397  51.492308  90.000000  0.0  0.0  207.000000   80.000000  6.800000
# 398  51.492308  80.000000  0.0  0.0  100.000000   49.000000  1.000000
#
#             sod       pot       hrmo  ...  rbc_normal  pc_normal  pcc_present  \
# ...

# %%
# Print the dep_Y
dep_Y
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 394     True
# 395     True
# 396     True
# 397     True
# 398    False
# Name: classification_yes, Length: 399, dtype: bool

# %%
# import regression related methods from feature_importance_regression
from feature_importance_regression import *

# %%
# get best features
ensemble_feature_list=permutation_feature_importance(indep_X,dep_Y,5, df2.columns)
# Out:
# LinearRegression()
# mean:::  [1.21806792e-04 3.56638481e-03 6.81796020e-03 3.40165841e-03
#  1.51833825e-02 1.67323429e-02 3.55016144e-03 3.27305062e-03
#  7.69717014e-04 2.49556735e-01 3.04849395e-03 2.49793971e-03
#  1.32312923e-03 2.72791797e-02 1.09488972e-01 1.36831241e-01
#  6.89218180e-03 4.09018671e-04 2.64191571e-03 7.99686421e-04
#  1.80332838e-03 2.41293717e-02 2.68335648e-02 1.02444236e-03
#  2.76589156e-03 3.12699874e-04 6.75205725e-03]
# mean arg sort:::  [ 0 25 17  8 19 23 12 20 11 18 24 10  7  3  6  1 26  2 16  4  5 21 22 13
#  14 15  9]
# Selected top 5 features index [ 9 15 14 13 22] for LinearRegression()
# hrmo    : 0.250 +/- 0.018
# sg_d    : 0.137 +/- 0.017
# sg_c    : 0.109 +/- 0.014
# sg_b    : 0.027 +/- 0.006
# dm_yes  : 0.027 +/- 0.006
# Selected top 5 features ['hrmo', 'sg_d', 'sg_c', 'sg_b', 'dm_yes'] for LinearRegression()
# sorted_importance ::  [1.21806792e-04 3.12699874e-04 4.09018671e-04 7.69717014e-04
# ...

# %%
# print selected features
ensemble_feature_list
# Out:
# ['sg_c',
#  'hrmo',
#  'al',
#  'sg_b',
#  'htn_yes',
#  'sc',
#  'bgr',
#  'dm_yes',
#  'pcv',
#  'rc',
#  'pc_normal',
#  'sg_d']

# %%
# Create empty list to store accuracy for each algorithms
acclin=[]
accsvml=[]
accsvmnl=[]
accdes=[]
accrf=[]

# %%
# Get all the required details from each algorithm and assign the accuracy to the respective list
  
X_train, X_test, y_train, y_test=split_scalar(indep_X[ensemble_feature_list],dep_Y)  
r2_lin=Linear(X_train,y_train,X_test,y_test)
acclin.append(r2_lin)

r2_sl=svm_linear(X_train,y_train,X_test,y_test)    
accsvml.append(r2_sl)

r2_NL=svm_NL(X_train,y_train,X_test,y_test)
accsvmnl.append(r2_NL)

r2_d=Decision(X_train,y_train,X_test,y_test)
accdes.append(r2_d)

r2_r=random_forest(X_train,y_train,X_test,y_test)
accrf.append(r2_r)

# %%
# get all the accuracy of each algorithm and print it in a dataframe
result=feature_importance_regression(acclin,accsvml,accsvmnl,accdes,accrf)

# %%
# result of  k = 3
result
# Out:
#             Linear      SVMl    SVM_NL  Decision    Random
# R2 score  0.705335  0.667254  0.931694  0.826389  0.866753

# %%
# result of  k = 4
result
# Out:
#             Linear      SVMl    SVM_NL  Decision    Random
# R2 score  0.704799  0.674446  0.926379  0.869792  0.885417

# %%
# result of  k = 5
result
# Out:
#             Linear      SVMl    SVM_NL  Decision    Random
# R2 score  0.705372  0.672303  0.944377  0.956597  0.863715

# %%
# result of  k = 6
result
# Out:
#             Linear      SVMl   SVM_NL  Decision    Random
# R2 score  0.713986  0.679654  0.93555  0.956597  0.858941

# %%
# result of k = 7
result
# Out:
#             Linear      SVMl    SVM_NL  Decision   Random
# R2 score  0.717544  0.693032  0.933316  0.826389  0.90191
